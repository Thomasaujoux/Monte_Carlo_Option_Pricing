# %%
import numpy as np
from scipy.stats import norm
from scipy.optimize import minimize

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Importation des valeurs

# %%
alpha = 0.15
b = 1.0
sigma = 0.2 
T = 1
r = 0.05
K = 4
k = 20
S_0 = 1

# %% [markdown]
# # Création du CIR

# %%
from CIR import CIR

# %%
S = CIR(alpha, b, sigma, T, k, S_0)

# %%
plt.plot(S)
plt.xlabel('Temps')
plt.ylabel('Position')
plt.title('CIR')
plt.show()
